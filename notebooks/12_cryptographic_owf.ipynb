# %% [markdown]
# # Goldreich OWF and Proposition 6
#
# Reproduces Section 5.1 and Table 6.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.family': 'serif', 'font.size': 12})

from src.cryptography import GoldreichOWF, owf_security_analysis, SecurityParameterTable

# %%
# Reproduce Table 6: security parameters
spt = SecurityParameterTable()
table6 = spt.reproduce_table6()
print("Table 6 reproduction:")
print(f"{'Label':10} | {'n':>5} | {'α':>5} | {'S (bits)':>10} | {'Matches':>8}")
for row in table6:
    print(f"{row['label']:10} | {row['n']:5d} | {row['alpha']:5.2f} | "
          f"{row['security_bits']:10.1f} | {row['matches_manuscript']}")
print(f"\nAll rows match manuscript: {spt.validate_table6()}")

# %%
# Full security analysis for n=400, α=4.20
owf = GoldreichOWF(n=400, alpha=4.20, seed=42)
analysis = owf.security_analysis()
print("\nProposition 6 security analysis (n=400, α=4.20):")
for k, v in analysis.items():
    if isinstance(v, float):
        print(f"  {k:30s} = {v:.4f}")
    else:
        print(f"  {k:30s} = {v}")
