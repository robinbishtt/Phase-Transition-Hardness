# %% [markdown]
# # Belief Propagation — Theorem 1 (Manuscript Eq. 6–7)
#
# Implements and validates the all-positive-gauge BP cavity equations.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.family': 'serif', 'font.size': 12})

from src.survey_propagation import BeliefPropagation
from src.instance_generator import generate_ksat_instance
from src.energy_model import ALPHA_D

# %%
# Test at α < α_AT ≈ 3.92 (RS phase — BP should converge)
inst_rs = generate_ksat_instance(20, 3.5, k=3, seed=42)
bp_rs   = BeliefPropagation(inst_rs, beta=3.0)
result_rs = bp_rs.run()
print(f"RS phase (α=3.5):  converged={result_rs.converged}, iterations={result_rs.n_iterations}")
print(f"  Free energy ≈ {result_rs.free_energy:.4f}")

# Test at α ≈ α_d (near clustering transition)
inst_d = generate_ksat_instance(20, 3.86, k=3, seed=42)
bp_d   = BeliefPropagation(inst_d, beta=5.0)
result_d = bp_d.run()
print(f"\nAt α_d (α=3.86):  converged={result_d.converged}, iterations={result_d.n_iterations}")
print(f"  Free energy ≈ {result_d.free_energy:.4f}")

# %%
# Show magnetisation distribution
mags = list(result_rs.magnetisations.values())
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(mags, bins=20, edgecolor='white')
ax.set_xlabel(r'Cavity magnetisation $m_{i \to a}$')
ax.set_ylabel('Count')
ax.set_title('BP magnetisation distribution at α=3.5 (RS phase)')
plt.tight_layout()
plt.savefig('../results/figures/nb10_bp_mags.png', dpi=150)
plt.show()
