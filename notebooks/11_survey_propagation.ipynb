# %% [markdown]
# # Survey Propagation — Theorem 2 (Manuscript Eq. 8–9)
#
# Implements the 1RSB cavity equations and the corrected complexity functional.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.family': 'serif', 'font.size': 12})

from src.survey_propagation import SurveyPropagation, WarningPropagation
from src.proofs.complexity_functional import ComplexityFunctional, compute_sp_complexity
from src.instance_generator import generate_ksat_instance

# %%
# Validate complexity Σ(α) at key values from manuscript
cf = ComplexityFunctional()
kv = cf.validate_key_values()
print("Complexity functional validation:")
print(f"  Σ(α_d=3.86) = {kv['sigma_at_alpha_d']:.6f}  (expected: 0)")
print(f"  Σ(α_s=4.267)= {kv['sigma_at_alpha_s']:.6f}  (expected: 0)")
print(f"  Σ(4.20)     = {kv['sigma_at_alpha_star']:.4f}  (manuscript: ≈0.027)")
print(f"  Σ_max       = {kv['sigma_max']:.4f}           (manuscript: ≈0.047 near α≈4.05)")
print(f"  Peak α      = {kv['sigma_peak_alpha']:.3f}     (manuscript: Figure S9)")

# %%
# Run SP on a hard-phase instance
inst_hard = generate_ksat_instance(15, 4.20, k=3, seed=42)
sp = SurveyPropagation(inst_hard)
sp_result = sp.run()
print(f"\nSP on n=15, α=4.20:")
print(f"  converged     = {sp_result.converged}")
print(f"  n_iterations  = {sp_result.n_iterations}")
print(f"  complexity    = {sp_result.complexity:.4f}")
print(f"  frozen_frac   = {sp_result.frozen_fraction:.4f}")

# Show biases
biases = list(sp_result.biases.values())
print(f"  |bias| > 0.7 (frozen): {sum(abs(b)>0.7 for b in biases)}/{len(biases)}")
